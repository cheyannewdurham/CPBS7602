# %%
from os.path import samefile

import pandas as pd
import numpy as np
from tensorboard.notebook import display

# %%
tpm_scaled_fp = "/Users/cheyanne/Library/Mobile Documents/com~apple~CloudDocs/github_repos/CPBS7602/assignment03/tpm_scaled.csv"
sp_fp = "/Users/cheyanne/Library/Mobile Documents/com~apple~CloudDocs/github_repos/CPBS7602/data/subject_phenotypes.txt"
sample_key_fp = "/Users/cheyanne/Library/Mobile Documents/com~apple~CloudDocs/github_repos/CPBS7602/data/sample_keys.csv"

# %%
from IPython.display import display  # Correct display function

tpm_scaled = pd.read_csv(tpm_scaled_fp, index_col=0)
display(tpm_scaled)
# Out:
#                 RP11-3J1.1  TMEM167B  RNA5SP19  RP11-388G3.1  CH17-264B6.4  \
# Tissue
# Adipose Tissue   -0.187192  1.878705 -0.149649     -0.330800     -0.163793
# Muscle           -0.187192 -0.142945 -0.149649     -0.330800     -0.163793
# Blood Vessel     -0.187192  1.376769 -0.149649      2.257657     -0.163793
# Blood Vessel     -0.187192  0.627176 -0.149649     -0.330800     -0.163793
# Heart             1.718123 -0.779966 -0.149649     -0.330800     -0.163793
# ...                    ...       ...       ...           ...           ...
# Thyroid          -0.187192 -0.021765 -0.149649     -0.330800     -0.163793
# Esophagus        -0.187192  0.182850 -0.149649     -0.330800     -0.163793
# Blood Vessel     -0.187192  0.739085 -0.149649     -0.330800     -0.163793
# Muscle            3.144438 -0.730965  3.720491      0.957501     -0.163793
# Adipose Tissue   -0.187192  0.843048 -0.149649     -0.330800     -0.163793
#
#                   BTG4P1  snoMe28S-Am2634     Y_RNA    ATXN1L  USP17L25  ...  \
# Tissue                                                                   ...
# Adipose Tissue -0.033556        -0.131723  7.039768  2.275804       0.0  ...
# Muscle         -0.033556        -0.131723 -0.154864 -0.226124       0.0  ...
# Blood Vessel   -0.033556        -0.131723 -0.154864  3.403667       0.0  ...
# Blood Vessel   -0.033556        -0.131723 -0.154864  0.605634       0.0  ...
# Heart          -0.033556        -0.131723 -0.154864 -0.923359       0.0  ...
# ...                  ...              ...       ...       ...       ...  ...
# Thyroid        -0.033556         3.320268 -0.154864  0.300656       0.0  ...
# Esophagus      -0.033556        -0.131723 -0.154864  0.988243       0.0  ...
# Blood Vessel   -0.033556        -0.131723 -0.154864  1.278803       0.0  ...
# Muscle         -0.033556        -0.131723 -0.154864 -0.708432       0.0  ...
# Adipose Tissue -0.033556        -0.131723 -0.154864  1.747915       0.0  ...
#
#                  COX7A2L   MIR500B    OR4G1P  RP11-76H14.2  RP11-43D4.3  \
# Tissue
# Adipose Tissue  1.008925 -0.025749 -0.205672      4.390730    -0.374691
# Muscle         -0.591819 -0.025749 -0.205672      0.155128    -0.374691
# Blood Vessel    0.931810 -0.025749  5.301855      2.682944    -0.374691
# Blood Vessel    0.630656 -0.025749 -0.205672     -0.598637     1.619849
# Heart          -0.883232 -0.025749 -0.205672     -0.598637    -0.374691
# ...                  ...       ...       ...           ...          ...
# Thyroid        -0.415672 -0.025749 -0.205672     -0.598637    -0.374691
# Esophagus      -0.659193 -0.025749 -0.205672      0.576105     0.457955
# Blood Vessel    0.404993 -0.025749 -0.205672      2.297047     0.651474
# Muscle         -1.366216 -0.025749 -0.205672     -0.598637    -0.374691
# Adipose Tissue  0.288103 -0.025749 -0.205672      0.100069    -0.374691
#
#                 MTND2P18  snoU13.4    MIR300   DEFB126    OR8B5P
# Tissue
# Adipose Tissue -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Muscle         -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Blood Vessel   -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Blood Vessel   -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Heart          -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# ...                  ...       ...       ...       ...       ...
# Thyroid        -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Esophagus      -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Blood Vessel   -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Muscle         -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# Adipose Tissue -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
#
# [12462 rows x 5000 columns]

# %%
sp = pd.read_csv(sp_fp, sep="\t")

# %%
display(sp)
# Out:
#          SUBJID  SEX    AGE  DTHHRDY
# 0    GTEX-1117F    2  60-69      4.0
# 1    GTEX-111CU    1  50-59      0.0
# 2    GTEX-111FC    1  60-69      1.0
# 3    GTEX-111VG    1  60-69      3.0
# 4    GTEX-111YS    1  60-69      0.0
# ..          ...  ...    ...      ...
# 975   GTEX-ZYY3    2  60-69      4.0
# 976   GTEX-ZZ64    1  20-29      0.0
# 977   GTEX-ZZPT    1  50-59      4.0
# 978   GTEX-ZZPU    2  50-59      0.0
# 979       K-562    2  50-59      NaN
#
# [980 rows x 4 columns]

# %%
sample_key = pd.read_csv(sample_key_fp, index_col=1)

# %%
display(sample_key)
# Out:
#                                SAMPID          Tissue
# Sample
# sample1      GTEX-1117F-0226-SM-5GZZ7  Adipose Tissue
# sample2      GTEX-1117F-0426-SM-5EGHI          Muscle
# sample3      GTEX-1117F-0526-SM-5EGHJ    Blood Vessel
# sample4      GTEX-1117F-0626-SM-5N9CS    Blood Vessel
# sample5      GTEX-1117F-0726-SM-5GIEN           Heart
# ...                               ...             ...
# sample12458   GTEX-ZZPU-1326-SM-5GZWS         Thyroid
# sample12459   GTEX-ZZPU-1826-SM-5E43L       Esophagus
# sample12460   GTEX-ZZPU-2426-SM-5E44I    Blood Vessel
# sample12461   GTEX-ZZPU-2626-SM-5E45Y          Muscle
# sample12462   GTEX-ZZPU-2726-SM-5NQ8O  Adipose Tissue
#
# [12462 rows x 2 columns]

# %%
tpm_scaled_df = tpm_scaled.set_index(sample_key.index)

# %%
display(tpm_scaled_df)
# Out:
#              RP11-3J1.1  TMEM167B  RNA5SP19  RP11-388G3.1  CH17-264B6.4  \
# Sample
# sample1       -0.187192  1.878705 -0.149649     -0.330800     -0.163793
# sample2       -0.187192 -0.142945 -0.149649     -0.330800     -0.163793
# sample3       -0.187192  1.376769 -0.149649      2.257657     -0.163793
# sample4       -0.187192  0.627176 -0.149649     -0.330800     -0.163793
# sample5        1.718123 -0.779966 -0.149649     -0.330800     -0.163793
# ...                 ...       ...       ...           ...           ...
# sample12458   -0.187192 -0.021765 -0.149649     -0.330800     -0.163793
# sample12459   -0.187192  0.182850 -0.149649     -0.330800     -0.163793
# sample12460   -0.187192  0.739085 -0.149649     -0.330800     -0.163793
# sample12461    3.144438 -0.730965  3.720491      0.957501     -0.163793
# sample12462   -0.187192  0.843048 -0.149649     -0.330800     -0.163793
#
#                BTG4P1  snoMe28S-Am2634     Y_RNA    ATXN1L  USP17L25  ...  \
# Sample                                                                ...
# sample1     -0.033556        -0.131723  7.039768  2.275804       0.0  ...
# sample2     -0.033556        -0.131723 -0.154864 -0.226124       0.0  ...
# sample3     -0.033556        -0.131723 -0.154864  3.403667       0.0  ...
# sample4     -0.033556        -0.131723 -0.154864  0.605634       0.0  ...
# sample5     -0.033556        -0.131723 -0.154864 -0.923359       0.0  ...
# ...               ...              ...       ...       ...       ...  ...
# sample12458 -0.033556         3.320268 -0.154864  0.300656       0.0  ...
# sample12459 -0.033556        -0.131723 -0.154864  0.988243       0.0  ...
# sample12460 -0.033556        -0.131723 -0.154864  1.278803       0.0  ...
# sample12461 -0.033556        -0.131723 -0.154864 -0.708432       0.0  ...
# sample12462 -0.033556        -0.131723 -0.154864  1.747915       0.0  ...
#
#               COX7A2L   MIR500B    OR4G1P  RP11-76H14.2  RP11-43D4.3  \
# Sample
# sample1      1.008925 -0.025749 -0.205672      4.390730    -0.374691
# sample2     -0.591819 -0.025749 -0.205672      0.155128    -0.374691
# sample3      0.931810 -0.025749  5.301855      2.682944    -0.374691
# sample4      0.630656 -0.025749 -0.205672     -0.598637     1.619849
# sample5     -0.883232 -0.025749 -0.205672     -0.598637    -0.374691
# ...               ...       ...       ...           ...          ...
# sample12458 -0.415672 -0.025749 -0.205672     -0.598637    -0.374691
# sample12459 -0.659193 -0.025749 -0.205672      0.576105     0.457955
# sample12460  0.404993 -0.025749 -0.205672      2.297047     0.651474
# sample12461 -1.366216 -0.025749 -0.205672     -0.598637    -0.374691
# sample12462  0.288103 -0.025749 -0.205672      0.100069    -0.374691
#
#              MTND2P18  snoU13.4    MIR300   DEFB126    OR8B5P
# Sample
# sample1     -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample2     -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample3     -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample4     -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample5     -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# ...               ...       ...       ...       ...       ...
# sample12458 -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample12459 -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample12460 -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample12461 -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
# sample12462 -0.138011 -0.062647 -0.069471 -0.143432 -0.129707
#
# [12462 rows x 5000 columns]

# %%
sample_key['Age'] = sample_key['SAMPID'].str.split('-').str[:2].str.join('-').map(sp.set_index('SUBJID')['AGE'])
display(sample_key)
# Out:
#                                SAMPID          Tissue    Age
# Sample
# sample1      GTEX-1117F-0226-SM-5GZZ7  Adipose Tissue  60-69
# sample2      GTEX-1117F-0426-SM-5EGHI          Muscle  60-69
# sample3      GTEX-1117F-0526-SM-5EGHJ    Blood Vessel  60-69
# sample4      GTEX-1117F-0626-SM-5N9CS    Blood Vessel  60-69
# sample5      GTEX-1117F-0726-SM-5GIEN           Heart  60-69
# ...                               ...             ...    ...
# sample12458   GTEX-ZZPU-1326-SM-5GZWS         Thyroid  50-59
# sample12459   GTEX-ZZPU-1826-SM-5E43L       Esophagus  50-59
# sample12460   GTEX-ZZPU-2426-SM-5E44I    Blood Vessel  50-59
# sample12461   GTEX-ZZPU-2626-SM-5E45Y          Muscle  50-59
# sample12462   GTEX-ZZPU-2726-SM-5NQ8O  Adipose Tissue  50-59
#
# [12462 rows x 3 columns]

# %%
print(sample_key)
# Out:
#                                SAMPID          Tissue    Age
# Sample
# sample1      GTEX-1117F-0226-SM-5GZZ7  Adipose Tissue  60-69
# sample2      GTEX-1117F-0426-SM-5EGHI          Muscle  60-69
# sample3      GTEX-1117F-0526-SM-5EGHJ    Blood Vessel  60-69
# sample4      GTEX-1117F-0626-SM-5N9CS    Blood Vessel  60-69
# sample5      GTEX-1117F-0726-SM-5GIEN           Heart  60-69
# ...                               ...             ...    ...
# sample12458   GTEX-ZZPU-1326-SM-5GZWS         Thyroid  50-59
# sample12459   GTEX-ZZPU-1826-SM-5E43L       Esophagus  50-59
# sample12460   GTEX-ZZPU-2426-SM-5E44I    Blood Vessel  50-59
# sample12461   GTEX-ZZPU-2626-SM-5E45Y          Muscle  50-59
# sample12462   GTEX-ZZPU-2726-SM-5NQ8O  Adipose Tissue  50-59
#
# [12462 rows x 3 columns]

# %%
age_mapping = {
    '20-29': 24.5,
    '30-39': 34.5,
    '40-49': 44.5,
    '50-59': 54.5,
    '60-69': 64.5,
    '70-79': 74.5,
    '80-89': 84.5
}

# %%
sample_key['Age'] = sample_key['Age'].replace(age_mapping)

display(sample_key)
# Out:
# /var/folders/xh/7tbpz8ds3jxdg4rq_w8ht19r0000gn/T/ipykernel_13981/1479068900.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sample_key['Age'] = sample_key['Age'].replace(age_mapping)
#                                SAMPID          Tissue   Age
# Sample
# sample1      GTEX-1117F-0226-SM-5GZZ7  Adipose Tissue  64.5
# sample2      GTEX-1117F-0426-SM-5EGHI          Muscle  64.5
# sample3      GTEX-1117F-0526-SM-5EGHJ    Blood Vessel  64.5
# sample4      GTEX-1117F-0626-SM-5N9CS    Blood Vessel  64.5
# sample5      GTEX-1117F-0726-SM-5GIEN           Heart  64.5
# ...                               ...             ...   ...
# sample12458   GTEX-ZZPU-1326-SM-5GZWS         Thyroid  54.5
# sample12459   GTEX-ZZPU-1826-SM-5E43L       Esophagus  54.5
# sample12460   GTEX-ZZPU-2426-SM-5E44I    Blood Vessel  54.5
# sample12461   GTEX-ZZPU-2626-SM-5E45Y          Muscle  54.5
# sample12462   GTEX-ZZPU-2726-SM-5NQ8O  Adipose Tissue  54.5
#
# [12462 rows x 3 columns]

# %%
blood_samples = sample_key[sample_key['Tissue'] == 'Blood']

display(blood_samples)
# Out:
#                                SAMPID Tissue   Age
# Sample
# sample37     GTEX-111YS-0006-SM-5NQBE  Blood  64.5
# sample53     GTEX-1122O-0003-SM-5Q5DL  Blood  64.5
# sample54     GTEX-1122O-0005-SM-5O99J  Blood  64.5
# sample72     GTEX-1128S-0005-SM-5P9HI  Blood  64.5
# sample84     GTEX-113IC-0006-SM-5NQ9C  Blood  64.5
# ...                               ...    ...   ...
# sample12284   GTEX-ZVZP-0006-SM-51MSW  Blood  54.5
# sample12297   GTEX-ZVZQ-0006-SM-51MR8  Blood  64.5
# sample12315   GTEX-ZXES-0004-SM-57WCW  Blood  34.5
# sample12316   GTEX-ZXES-0005-SM-57WCB  Blood  34.5
# sample12325   GTEX-ZXG5-0005-SM-57WCN  Blood  64.5
#
# [929 rows x 3 columns]

# %% [markdown]
# ### Prep PCA to UMAP latent spaces

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import umap
from sklearn.cluster import SpectralClustering

# %%
# Step 1: Reduce data with PCA
pca = PCA(n_components=7, random_state=42)
pca_data = pca.fit_transform(tpm_scaled)

# Step 2: Reduce PCA data to 3D using UMAP
umap3_model = umap.UMAP(n_components=3, n_neighbors=10, min_dist=0.1, random_state=42)
umap3_data = umap3_model.fit_transform(pca_data)

# Step 3: Spectral Clustering on UMAP-reduced data
spectral = SpectralClustering(n_clusters=10, affinity='rbf', gamma=0.1, random_state=42)
cluster_labels = spectral.fit_predict(umap3_data)

# Step 3: Create a DataFrame for plotting
umap3_df = pd.DataFrame(umap3_data, columns=['UMAP1', 'UMAP2', 'UMAP3'])
umap3_df['Cluster'] = cluster_labels  # Add cluster labels from Spectral Clustering

# Step 5: Plot Spectral Clustering Results with distinct colors
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

# Use Seaborn's 'Set1' or 'bright' palette for high contrast
palette = sns.color_palette('Set1', n_colors=umap3_df['Cluster'].nunique())

# Plot each cluster
for label in umap3_df['Cluster'].unique():
    subset = umap3_df[umap3_df['Cluster'] == label]
    ax.scatter(subset['UMAP1'], subset['UMAP2'], subset['UMAP3'],
               color=palette[label], label=f'Cluster {label}', s=2, alpha=1)  # Adjust point size and opacity

# Add labels and titles
ax.set_title('PCA → UMAP → Spectral Clustering')
ax.set_xlabel('UMAP1')
ax.set_ylabel('UMAP2')
ax.set_zlabel('UMAP3')
ax.legend(bbox_to_anchor=(1.1, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# /Users/cheyanne/miniconda3/envs/cpbs7602/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
# Step 1: Reduce data with PCA
pca = PCA(n_components=7, random_state=42)
pca_data = pca.fit_transform(tpm_scaled)

# Step 2: Reduce PCA data to 2D using UMAP
umap2_model = umap.UMAP(n_components=2, n_neighbors=10, min_dist=0.1, random_state=42)
umap2_data = umap2_model.fit_transform(pca_data)

# Step 3: Spectral Clustering on UMAP-reduced data
spectral = SpectralClustering(n_clusters=10, affinity='rbf', gamma=0.1, random_state=42)
cluster_labels = spectral.fit_predict(umap2_data)

# Step 3: Create a DataFrame for plotting
umap2_df = pd.DataFrame(umap2_data, columns=['UMAP1', 'UMAP2'])
umap2_df['Cluster'] = cluster_labels  # Add cluster labels from Spectral Clustering

# Step 4: Plot the 2D UMAP visualization
plt.figure(figsize=(10, 8))

# Define a diverse color palette for the clusters
palette = sns.color_palette('Set1', n_colors=len(umap2_df['Cluster'].unique()))

# Plot each cluster
for label in umap2_df['Cluster'].unique():
    subset = umap2_df[umap2_df['Cluster'] == label]
    plt.scatter(subset['UMAP1'], subset['UMAP2'], color=palette[label],
                label=f'Cluster {label}', s=30, alpha=0.7)  # Adjust size and transparency

# Add labels and title
plt.title('PCA (50D) → UMAP (2D) → Spectral Clustering')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /Users/cheyanne/miniconda3/envs/cpbs7602/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.metrics import classification_report, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

# %%
tissue_labels = tpm_scaled.index
print(tissue_labels)
umap3_df = pd.DataFrame(umap3_data, columns=['UMAP1', 'UMAP2', 'UMAP3'])
umap3_df['Tissue'] = tissue_labels
display(umap3_df)
umap2_df = pd.DataFrame(umap2_data, columns=['UMAP1', 'UMAP2'])
umap2_df['Tissue'] = tissue_labels
display(umap2_df)
# label encoding for tissues
le = LabelEncoder()
umap3_df['Tissue_Encoded'] = le.fit_transform(umap3_df['Tissue'])
umap2_df['Tissue_Encoded'] = le.fit_transform(umap2_df['Tissue'])
# Out:
# Index(['Adipose Tissue', 'Muscle', 'Blood Vessel', 'Blood Vessel', 'Heart',
#        'Adipose Tissue', 'Skin', 'Brain', 'Thyroid', 'Esophagus',
#        ...
#        'Adipose Tissue', 'Skin', 'Heart', 'Blood Vessel', 'Heart', 'Thyroid',
#        'Esophagus', 'Blood Vessel', 'Muscle', 'Adipose Tissue'],
#       dtype='object', name='Tissue', length=12462)
#           UMAP1      UMAP2      UMAP3          Tissue
# 0     -1.244323   6.201374   2.859681  Adipose Tissue
# 1     -3.982232  -0.801024  10.199581          Muscle
# 2     -0.948698   5.916493   2.705319    Blood Vessel
# 3     -0.802581   5.488636   1.942061    Blood Vessel
# 4     -3.222689   0.888006  10.917901           Heart
# ...         ...        ...        ...             ...
# 12457  0.653429  11.121228   5.374468         Thyroid
# 12458 -0.868744   2.456550   5.947646       Esophagus
# 12459 -0.392737   2.766480   3.511460    Blood Vessel
# 12460 -3.815824  -1.988101  10.673391          Muscle
# 12461 -3.213875   4.641685   5.272733  Adipose Tissue
#
# [12462 rows x 4 columns]
#           UMAP1     UMAP2          Tissue
# 0     -0.950565  2.404740  Adipose Tissue
# 1     -0.304636  6.490026          Muscle
# 2     -0.778869  1.845492    Blood Vessel
# 3     -0.186089  0.556760    Blood Vessel
# 4     -2.375582  6.711559           Heart
# ...         ...       ...             ...
# 12457  6.770709  8.101522         Thyroid
# 12458 -5.068172 -0.413052       Esophagus
# 12459 -2.598371 -1.551081    Blood Vessel
# 12460  0.896656  6.268530          Muscle
# 12461 -4.183198  3.977167  Adipose Tissue
#
# [12462 rows x 3 columns]

# %%
# Step 1: Ensure umap2_df and umap3_df have the correct index from sample_key
umap2_df = umap2_df.set_index(sample_key.index)
umap3_df = umap3_df.set_index(sample_key.index)

# Verify
print(umap2_df.head())
print(umap3_df.head())
# Out:
#             UMAP1     UMAP2          Tissue  Tissue_Encoded
# Sample
# sample1 -0.950565  2.404740  Adipose Tissue               0
# sample2 -0.304636  6.490026          Muscle               7
# sample3 -0.778869  1.845492    Blood Vessel               2
# sample4 -0.186089  0.556760    Blood Vessel               2
# sample5 -2.375582  6.711559           Heart               6
#             UMAP1     UMAP2      UMAP3          Tissue  Tissue_Encoded
# Sample
# sample1 -1.244323  6.201374   2.859681  Adipose Tissue               0
# sample2 -3.982232 -0.801024  10.199581          Muscle               7
# sample3 -0.948698  5.916493   2.705319    Blood Vessel               2
# sample4 -0.802581  5.488636   1.942061    Blood Vessel               2
# sample5 -3.222689  0.888006  10.917901           Heart               6

# %% [markdown]
# ### Incorporate Blood samples data into latent spaces

# %%
# Merge the blood_samples DataFrame with latent spaces using the index
blood_latent_2d = blood_samples.merge(umap2_df, left_index=True, right_index=True)
blood_latent_3d = blood_samples.merge(umap3_df, left_index=True, right_index=True)

# Check results
print(blood_latent_2d.shape)
print(blood_latent_3d.shape)
print(blood_latent_2d.head())
print(blood_latent_3d.head())
# Out:
# (929, 7)
# (929, 8)
#                             SAMPID Tissue_x   Age     UMAP1     UMAP2  \
# Sample
# sample37  GTEX-111YS-0006-SM-5NQBE    Blood  64.5 -1.203676 -4.931715
# sample53  GTEX-1122O-0003-SM-5Q5DL    Blood  64.5  3.048994 -7.728689
# sample54  GTEX-1122O-0005-SM-5O99J    Blood  64.5 -6.391925 -3.779353
# sample72  GTEX-1128S-0005-SM-5P9HI    Blood  64.5 -6.192423 -4.255239
# sample84  GTEX-113IC-0006-SM-5NQ9C    Blood  64.5 -7.311543 -3.517231
#
#          Tissue_y  Tissue_Encoded
# Sample
# sample37    Blood               1
# sample53    Blood               1
# sample54    Blood               1
# sample72    Blood               1
# sample84    Blood               1
#                             SAMPID Tissue_x   Age     UMAP1     UMAP2  \
# Sample
# sample37  GTEX-111YS-0006-SM-5NQBE    Blood  64.5  1.500119 -0.525037
# sample53  GTEX-1122O-0003-SM-5Q5DL    Blood  64.5  4.462552  0.390294
# sample54  GTEX-1122O-0005-SM-5O99J    Blood  64.5  0.910642  1.122686
# sample72  GTEX-1128S-0005-SM-5P9HI    Blood  64.5  0.937510  1.161071
# sample84  GTEX-113IC-0006-SM-5NQ9C    Blood  64.5  0.759722  2.137545
#
#               UMAP3 Tissue_y  Tissue_Encoded
# Sample
# sample37  17.003752    Blood               1
# sample53  -2.520929    Blood               1
# sample54  16.408051    Blood               1
# sample72  16.910429    Blood               1
# sample84  16.161289    Blood               1

# %%
# Merge blood_data with latent space features (e.g., UMAP2 or UMAP3)
blood_latent_2d = blood_samples.merge(umap2_df)
blood_latent_3d = blood_samples.merge(umap3_df)
# Check the shape of the resulting datasets
print(blood_latent_2d.shape)
print(blood_latent_3d.shape)
# Out:
# (863041, 6)
# (863041, 7)

# %%
print(blood_samples.head())
print(umap2_df.head())
print(umap3_df.head())
# Out:
#                             SAMPID Tissue   Age
# Sample
# sample37  GTEX-111YS-0006-SM-5NQBE  Blood  64.5
# sample53  GTEX-1122O-0003-SM-5Q5DL  Blood  64.5
# sample54  GTEX-1122O-0005-SM-5O99J  Blood  64.5
# sample72  GTEX-1128S-0005-SM-5P9HI  Blood  64.5
# sample84  GTEX-113IC-0006-SM-5NQ9C  Blood  64.5
#             UMAP1     UMAP2          Tissue  Tissue_Encoded
# Sample
# sample1 -0.950565  2.404740  Adipose Tissue               0
# sample2 -0.304636  6.490026          Muscle               7
# sample3 -0.778869  1.845492    Blood Vessel               2
# sample4 -0.186089  0.556760    Blood Vessel               2
# sample5 -2.375582  6.711559           Heart               6
#             UMAP1     UMAP2      UMAP3          Tissue  Tissue_Encoded
# Sample
# sample1 -1.244323  6.201374   2.859681  Adipose Tissue               0
# sample2 -3.982232 -0.801024  10.199581          Muscle               7
# sample3 -0.948698  5.916493   2.705319    Blood Vessel               2
# sample4 -0.802581  5.488636   1.942061    Blood Vessel               2
# sample5 -3.222689  0.888006  10.917901           Heart               6

# %% [markdown]
# ### Prep training and testing data

# %%
X_3d = blood_latent_3d[['UMAP1', 'UMAP2', 'UMAP3']]
y_3d = blood_latent_3d['Age']

X_2d = blood_latent_2d[['UMAP1', 'UMAP2']]
y_2d = blood_latent_2d['Age']


# Create age bins for stratification, drop duplicate edges
y_3d_bins = pd.qcut(y_3d, q=5, labels=False, duplicates='drop')
y_2d_bins = pd.qcut(y_2d, q=5, labels=False, duplicates='drop')

# Split with stratification using age bins
X_train_3d, X_test_3d, y_train_3d, y_test_3d = train_test_split(
    X_3d, y_3d, test_size=0.2, random_state=42, stratify=y_3d_bins
)

X_train_2d, X_test_2d, y_train_2d, y_test_2d = train_test_split(
    X_2d, y_2d, test_size=0.2, random_state=42, stratify=y_2d_bins
)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# Define parameters for Grid Search
rf_params = {'n_estimators': [100, 200], 'max_depth': [10, 20, None], 'random_state': [42]}
gb_params = {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1], 'max_depth': [3, 5], 'random_state': [42]}

# Initialize models
rf = GridSearchCV(RandomForestRegressor(), param_grid=rf_params, cv=5, n_jobs=-1)
gb = GridSearchCV(GradientBoostingRegressor(), param_grid=gb_params, cv=5, n_jobs=-1)

# Train on 2D data
rf.fit(X_train_2d, y_train_2d)
gb.fit(X_train_2d, y_train_2d)

# Predict and evaluate
rf_pred = rf.predict(X_test_2d)
gb_pred = gb.predict(X_test_2d)

print("Random Forest (2D) RMSE:", mean_squared_error(y_test_2d, rf_pred, squared=False))
print("Random Forest (2D) R2 Score:", r2_score(y_test_2d, rf_pred))

print("Gradient Boosting (2D) RMSE:", mean_squared_error(y_test_2d, gb_pred, squared=False))
print("Gradient Boosting (2D) R2 Score:", r2_score(y_test_2d, gb_pred))
# Out:
# Random Forest (2D) RMSE: 13.112808432136239
# Random Forest (2D) R2 Score: -0.0006200163986236351
# Gradient Boosting (2D) RMSE: 13.109047562709282
# Gradient Boosting (2D) R2 Score: -4.612536872672379e-05
# /Users/cheyanne/miniconda3/envs/cpbs7602/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/cheyanne/miniconda3/envs/cpbs7602/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Define parameters for Grid Search
rf_params = {'n_estimators': [100, 200], 'max_depth': [10, 20, None], 'random_state': [42]}
gb_params = {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1], 'max_depth': [3, 5], 'random_state': [42]}

# Initialize models
rf = GridSearchCV(RandomForestRegressor(), param_grid=rf_params, cv=5, n_jobs=-1)
gb = GridSearchCV(GradientBoostingRegressor(), param_grid=gb_params, cv=5, n_jobs=-1)

# Train on 3D data
rf.fit(X_train_3d, y_train_3d)
gb.fit(X_train_3d, y_train_3d)

# Predict and evaluate
rf_pred_3d = rf.predict(X_test_3d)
gb_pred_3d = gb.predict(X_test_3d)

print("Random Forest (3D) RMSE:", mean_squared_error(y_test_3d, rf_pred_3d, squared=False))
print("Random Forest (3D) R2 Score:", r2_score(y_test_3d, rf_pred_3d))

print("Gradient Boosting (3D) RMSE:", mean_squared_error(y_test_3d, gb_pred_3d, squared=False))
print("Gradient Boosting (3D) R2 Score:", r2_score(y_test_3d, gb_pred_3d))
# Out:
# Random Forest (3D) RMSE: 13.113282010562331
# Random Forest (3D) R2 Score: -0.0006922939144657914
# Gradient Boosting (3D) RMSE: 13.109112873355425
# Gradient Boosting (3D) R2 Score: -5.609006234896796e-05
# /Users/cheyanne/miniconda3/envs/cpbs7602/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/cheyanne/miniconda3/envs/cpbs7602/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
print("Best Random Forest Parameters (3D):", rf.best_params_)
print("Best Gradient Boosting Parameters (3D):", gb.best_params_)
# Out:
# Best Random Forest Parameters (3D): {'max_depth': 10, 'n_estimators': 200, 'random_state': 42}
# Best Gradient Boosting Parameters (3D): {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'random_state': 42}

# %%
print(y_3d.describe())
print(y_2d.describe())
# Out:
# count    863041.000000
# mean         52.131862
# std          13.082099
# min          24.500000
# 25%          44.500000
# 50%          54.500000
# 75%          64.500000
# max          74.500000
# Name: Age, dtype: float64
# count    863041.000000
# mean         52.131862
# std          13.082099
# min          24.500000
# 25%          44.500000
# 50%          54.500000
# 75%          64.500000
# max          74.500000
# Name: Age, dtype: float64

# %%
# Select only numeric columns for correlation
numeric_columns = blood_latent_3d.select_dtypes(include=[np.number])

# Compute correlations and display the correlation of Age
correlations = numeric_columns.corr()['Age']
print(correlations)
# Out:
# Age               1.000000e+00
# UMAP1            -2.092155e-15
# UMAP2            -8.324060e-17
# UMAP3             2.529971e-15
# Tissue_Encoded             NaN
# Name: Age, dtype: float64

# %%
correlations = numeric_columns.corr(method='spearman')['Age']
print(correlations)
# Out:
# Age               1.0
# UMAP1             0.0
# UMAP2             0.0
# UMAP3             0.0
# Tissue_Encoded    NaN
# Name: Age, dtype: float64
